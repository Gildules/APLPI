# %%
import os
import numpy as np
import struct
import time
from pyopenms import MSExperiment, MSSpectrum, Peak1D, FileHandler, SpectrumAlignment

def convert_tof_to_mzml(input_filename, output_folder):
    # Проверка и создание выходной директории
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Определение имени выходного файла на основе входного и папки назначения
    output_filename = os.path.join(output_folder, os.path.basename(input_filename).replace('.tof', '.mzML'))

    # Открытие входного файла в бинарном режиме
    with open(input_filename, 'rb') as fid:
        # Переход к позиции, где хранится количество спектров и количество точек на спектр
        fid.seek(278)
        numMS = struct.unpack('I', fid.read(4))[0]  # Чтение количества спектров
        numPn = struct.unpack('I', fid.read(4))[0]  # Чтение количества точек на спектр

        # Переход к позиции, где хранятся калибровочные коэффициенты
        fid.seek(286)
        AA = struct.unpack('d', fid.read(8))[0]  # Чтение коэффициента AA
        BB = struct.unpack('d', fid.read(8))[0]  # Чтение коэффициента BB
        
        # Вычисление шкалы m/z с использованием калибровочных коэффициентов
        zz_read = AA * ((np.arange(numPn)) + BB) ** 2

        # Переход к позиции, где начинаются данные спектров
        fid.seek(512)
        MS_1 = np.zeros((numMS, numPn), dtype=int)  # Инициализация массива для хранения данных всех спектров

        # Определение значений для типов данных (константы)
        fi_t1 = 0x4000
        fi_t2 = 0x8000
        fi_t3 = 0xc000
        fi_3f = 0x3fff

        # Инициализация объекта MSExperiment для хранения всех спектров
        experiment = MSExperiment()

        # Обработка каждого спектра
        for ii in range(numMS):
            start_time = time.time()  # Время начала обработки спектра
            arr = np.zeros(numPn, dtype=int)  # Инициализация массива для хранения данных одного спектра
            i1, i0, nB = 1, 1, 1  # Инициализация индексов

            # Чтение пакетов данных спектра
            npPack = struct.unpack('I', fid.read(4))[0]
            Buf_pack = np.frombuffer(fid.read(npPack * 2), dtype=np.uint16)
            nbArrP = struct.unpack('I', fid.read(4))[0]
            Buf_MS = np.frombuffer(fid.read(nbArrP), dtype=np.uint8)

            # Обработка каждого пакета данных
            for p in range(npPack):
                fi_type = Buf_pack[p]  # Тип данных пакета
                type = fi_type & fi_t3  # Маска типа данных
                c = fi_type & fi_3f  # Маска значений данных

                i1 = i0 + c  # Обновление индекса

                # Обработка данных в зависимости от типа
                if type == fi_t1:
                    arr[i0-1:i1-1] = Buf_MS[nB-1:nB+i1-i0-1]
                    nB += i1 - i0
                elif type == fi_t2:
                    idx_range = np.arange(nB-1, nB+2*(i1-i0-1), 2)
                    if len(idx_range) > len(arr[i0-1:i1-1]):
                        idx_range = idx_range[:len(arr[i0-1:i1-1])]
                    arr[i0-1:i1-1] = Buf_MS[idx_range] + 256*Buf_MS[idx_range + 1]
                    nB += 2 * (i1 - i0)
                elif type == fi_t3:
                    idx_range = np.arange(nB-1, nB+4*(i1-i0-1), 4)
                    if len(idx_range) > len(arr[i0-1:i1-1]):
                        idx_range = idx_range[:len(arr[i0-1:i1-1])]
                    arr[i0-1:i1-1] = Buf_MS[idx_range] + 256*Buf_MS[idx_range + 1] + \
                                     65536*Buf_MS[idx_range + 2] + 16777216*Buf_MS[idx_range + 3]
                    nB += 4 * (i1 - i0)

                i0 = i1  # Обновление начального индекса

            MS_1[ii, :] = arr  # Сохранение данных спектра в общий массив
            print(f'Spectrum {ii + 1}/{numMS} processed.')  # Уведомление о завершении обработки спектра

            # Создание объекта MSSpectrum и заполнение его данными
            spectrum = MSSpectrum()
            spectrum.setMSLevel(1)  # Установка уровня MS
            spectrum.set_peaks([zz_read, arr])

            # Добавление метаданных
            scan_time = float(ii)   # Время сканирования соответствует индексу спектра (в минутах)
            total_ion_current = float(np.sum(arr))  # Total Ion Current
            base_peak_intensity = float(np.max(arr))  # Интенсивность базового пика
            base_peak_mz = float(zz_read[np.argmax(arr)])  # Base Peak m/z

            spectrum.setRT(scan_time)
            spectrum.setMetaValue("total ion current", total_ion_current)
            spectrum.setMetaValue("base peak intensity", base_peak_intensity)
            spectrum.setMetaValue("base peak m/z", base_peak_mz)

            # Добавление спектра в эксперимент
            experiment.addSpectrum(spectrum)

    # Выровнять спектры с использованием SpectrumAlignment
    aligner = SpectrumAlignment()
    params = aligner.getParameters()
    params.setValue("tolerance", 0.1)  # Установка толерантности для выравнивания
    params.setValue("is_relative_tolerance", "true")
    aligner.setParameters(params)

    for i in range(1, experiment.getNrSpectra()):
        spectrum1 = experiment.getSpectrum(i - 1)
        spectrum2 = experiment.getSpectrum(i)
        alignment = []
        aligner.getSpectrumAlignment(alignment, spectrum1, spectrum2)
        # Применение выравнивания к спектрам (это может включать изменение m/z значений или интенсивностей)

    # Сохранение эксперимента в файл mzML
    try:
        FileHandler().storeExperiment(output_filename, experiment)
        print(f'{output_filename} "сгенерирован"')
    except Exception as e:
        print(f'Ошибка при сохранении файла: {e}')

# Пример использования функции
convert_tof_to_mzml('air_chudo_1_1.tof', './path')
# Out:
# Spectrum 1/453 processed.
# Spectrum 2/453 processed.
# Spectrum 3/453 processed.
# Spectrum 4/453 processed.
# Spectrum 5/453 processed.
# Spectrum 6/453 processed.
# Spectrum 7/453 processed.
# Spectrum 8/453 processed.
# Spectrum 9/453 processed.
# Spectrum 10/453 processed.
# Spectrum 11/453 processed.
# Spectrum 12/453 processed.
# Spectrum 13/453 processed.
# Spectrum 14/453 processed.
# Spectrum 15/453 processed.
# Spectrum 16/453 processed.
# Spectrum 17/453 processed.
# Spectrum 18/453 processed.
# Spectrum 19/453 processed.
# Spectrum 20/453 processed.
# Spectrum 21/453 processed.
# Spectrum 22/453 processed.
# Spectrum 23/453 processed.
# Spectrum 24/453 processed.
# Spectrum 25/453 processed.
# Spectrum 26/453 processed.
# Spectrum 27/453 processed.
# Spectrum 28/453 processed.
# Spectrum 29/453 processed.
# Spectrum 30/453 processed.
# Spectrum 31/453 processed.
# Spectrum 32/453 processed.
# Spectrum 33/453 processed.
# Spectrum 34/453 processed.
# Spectrum 35/453 processed.
# Spectrum 36/453 processed.
# Spectrum 37/453 processed.
# Spectrum 38/453 processed.
# Spectrum 39/453 processed.
# Spectrum 40/453 processed.
# Spectrum 41/453 processed.
# Spectrum 42/453 processed.
# Spectrum 43/453 processed.
# Spectrum 44/453 processed.
# Spectrum 45/453 processed.
# Spectrum 46/453 processed.
# Spectrum 47/453 processed.
# Spectrum 48/453 processed.
# Spectrum 49/453 processed.
# Spectrum 50/453 processed.
# Spectrum 51/453 processed.
# Spectrum 52/453 processed.
# Spectrum 53/453 processed.
# Spectrum 54/453 processed.
# Spectrum 55/453 processed.
# Spectrum 56/453 processed.
# Spectrum 57/453 processed.
# Spectrum 58/453 processed.
# Spectrum 59/453 processed.
# Spectrum 60/453 processed.
# Spectrum 61/453 processed.
# Spectrum 62/453 processed.
# Spectrum 63/453 processed.
# Spectrum 64/453 processed.
# Spectrum 65/453 processed.
# Spectrum 66/453 processed.
# Spectrum 67/453 processed.
# Spectrum 68/453 processed.
# Spectrum 69/453 processed.
# Spectrum 70/453 processed.
# Spectrum 71/453 processed.
# Spectrum 72/453 processed.
# Spectrum 73/453 processed.
# Spectrum 74/453 processed.
# Spectrum 75/453 processed.
# Spectrum 76/453 processed.
# Spectrum 77/453 processed.
# Spectrum 78/453 processed.
# Spectrum 79/453 processed.
# Spectrum 80/453 processed.
# Spectrum 81/453 processed.
# Spectrum 82/453 processed.
# Spectrum 83/453 processed.
# Spectrum 84/453 processed.
# Spectrum 85/453 processed.
# Spectrum 86/453 processed.
# Spectrum 87/453 processed.
# Spectrum 88/453 processed.
# Spectrum 89/453 processed.
# Spectrum 90/453 processed.
# Spectrum 91/453 processed.
# Spectrum 92/453 processed.
# Spectrum 93/453 processed.
# Spectrum 94/453 processed.
# Spectrum 95/453 processed.
# Spectrum 96/453 processed.
# Spectrum 97/453 processed.
# Spectrum 98/453 processed.
# Spectrum 99/453 processed.
# Spectrum 100/453 processed.
# Spectrum 101/453 processed.
# Spectrum 102/453 processed.
# Spectrum 103/453 processed.
# Spectrum 104/453 processed.
# Spectrum 105/453 processed.
# Spectrum 106/453 processed.
# Spectrum 107/453 processed.
# Spectrum 108/453 processed.
# Spectrum 109/453 processed.
# Spectrum 110/453 processed.
# Spectrum 111/453 processed.
# Spectrum 112/453 processed.
# Spectrum 113/453 processed.
# Spectrum 114/453 processed.
# Spectrum 115/453 processed.
# Spectrum 116/453 processed.
# Spectrum 117/453 processed.
# Spectrum 118/453 processed.
# Spectrum 119/453 processed.
# Spectrum 120/453 processed.
# Spectrum 121/453 processed.
# Spectrum 122/453 processed.
# Spectrum 123/453 processed.
# Spectrum 124/453 processed.
# Spectrum 125/453 processed.
# Spectrum 126/453 processed.
# Spectrum 127/453 processed.
# Spectrum 128/453 processed.
# Spectrum 129/453 processed.
# Spectrum 130/453 processed.
# Spectrum 131/453 processed.
# Spectrum 132/453 processed.
# Spectrum 133/453 processed.
# Spectrum 134/453 processed.
# Spectrum 135/453 processed.
# Spectrum 136/453 processed.
# Spectrum 137/453 processed.
# Spectrum 138/453 processed.
# Spectrum 139/453 processed.
# Spectrum 140/453 processed.
# Spectrum 141/453 processed.
# Spectrum 142/453 processed.
# Spectrum 143/453 processed.
# Spectrum 144/453 processed.
# Spectrum 145/453 processed.
# Spectrum 146/453 processed.
# Spectrum 147/453 processed.
# Spectrum 148/453 processed.
# Spectrum 149/453 processed.
# Spectrum 150/453 processed.
# Spectrum 151/453 processed.
# Spectrum 152/453 processed.
# Spectrum 153/453 processed.
# Spectrum 154/453 processed.
# Spectrum 155/453 processed.
# Spectrum 156/453 processed.
# Spectrum 157/453 processed.
# Spectrum 158/453 processed.
# Spectrum 159/453 processed.
# Spectrum 160/453 processed.
# Spectrum 161/453 processed.
# Spectrum 162/453 processed.
# Spectrum 163/453 processed.
# Spectrum 164/453 processed.
# Spectrum 165/453 processed.
# Spectrum 166/453 processed.
# Spectrum 167/453 processed.
# Spectrum 168/453 processed.
# Spectrum 169/453 processed.
# Spectrum 170/453 processed.
# Spectrum 171/453 processed.
# Spectrum 172/453 processed.
# Spectrum 173/453 processed.
# Spectrum 174/453 processed.
# Spectrum 175/453 processed.
# Spectrum 176/453 processed.
# Spectrum 177/453 processed.
# Spectrum 178/453 processed.
# Spectrum 179/453 processed.
# Spectrum 180/453 processed.
# Spectrum 181/453 processed.
# Spectrum 182/453 processed.
# Spectrum 183/453 processed.
# Spectrum 184/453 processed.
# Spectrum 185/453 processed.
# Spectrum 186/453 processed.
# Spectrum 187/453 processed.
# Spectrum 188/453 processed.
# Spectrum 189/453 processed.
# Spectrum 190/453 processed.
# Spectrum 191/453 processed.
# Spectrum 192/453 processed.
# Spectrum 193/453 processed.
# Spectrum 194/453 processed.
# Spectrum 195/453 processed.
# Spectrum 196/453 processed.
# Spectrum 197/453 processed.
# Spectrum 198/453 processed.
# Spectrum 199/453 processed.
# Spectrum 200/453 processed.
# Spectrum 201/453 processed.
# Spectrum 202/453 processed.
# Spectrum 203/453 processed.
# Spectrum 204/453 processed.
# Spectrum 205/453 processed.
# Spectrum 206/453 processed.
# Spectrum 207/453 processed.
# Spectrum 208/453 processed.
# Spectrum 209/453 processed.
# Spectrum 210/453 processed.
# Spectrum 211/453 processed.
# Spectrum 212/453 processed.
# Spectrum 213/453 processed.
# Spectrum 214/453 processed.
# Spectrum 215/453 processed.
# Spectrum 216/453 processed.
# Spectrum 217/453 processed.
# Spectrum 218/453 processed.
# Spectrum 219/453 processed.
# Spectrum 220/453 processed.
# Spectrum 221/453 processed.
# Spectrum 222/453 processed.
# Spectrum 223/453 processed.
# Spectrum 224/453 processed.
# Spectrum 225/453 processed.
# Spectrum 226/453 processed.
# Spectrum 227/453 processed.
# Spectrum 228/453 processed.
# Spectrum 229/453 processed.
# Spectrum 230/453 processed.
# Spectrum 231/453 processed.
# Spectrum 232/453 processed.
# Spectrum 233/453 processed.
# Spectrum 234/453 processed.
# Spectrum 235/453 processed.
# Spectrum 236/453 processed.
# Spectrum 237/453 processed.
# Spectrum 238/453 processed.
# Spectrum 239/453 processed.
# Spectrum 240/453 processed.
# Spectrum 241/453 processed.
# Spectrum 242/453 processed.
# Spectrum 243/453 processed.
# Spectrum 244/453 processed.
# Spectrum 245/453 processed.
# Spectrum 246/453 processed.
# Spectrum 247/453 processed.
# Spectrum 248/453 processed.
# Spectrum 249/453 processed.
# Spectrum 250/453 processed.
# Spectrum 251/453 processed.
# Spectrum 252/453 processed.
# Spectrum 253/453 processed.
# Spectrum 254/453 processed.
# Spectrum 255/453 processed.
# Spectrum 256/453 processed.
# Spectrum 257/453 processed.
# Spectrum 258/453 processed.
# Spectrum 259/453 processed.
# Spectrum 260/453 processed.
# Spectrum 261/453 processed.
# Spectrum 262/453 processed.
# Spectrum 263/453 processed.
# Spectrum 264/453 processed.
# Spectrum 265/453 processed.
# Spectrum 266/453 processed.
# Spectrum 267/453 processed.
# Spectrum 268/453 processed.
# Spectrum 269/453 processed.
# Spectrum 270/453 processed.
# Spectrum 271/453 processed.
# Spectrum 272/453 processed.
# Spectrum 273/453 processed.
# Spectrum 274/453 processed.
# Spectrum 275/453 processed.
# Spectrum 276/453 processed.
# Spectrum 277/453 processed.
# Spectrum 278/453 processed.
# Spectrum 279/453 processed.
# Spectrum 280/453 processed.
# Spectrum 281/453 processed.
# Spectrum 282/453 processed.
# Spectrum 283/453 processed.
# Spectrum 284/453 processed.
# Spectrum 285/453 processed.
# Spectrum 286/453 processed.
# Spectrum 287/453 processed.
# Spectrum 288/453 processed.
# Spectrum 289/453 processed.
# Spectrum 290/453 processed.
# Spectrum 291/453 processed.
# Spectrum 292/453 processed.
# Spectrum 293/453 processed.
# Spectrum 294/453 processed.
# Spectrum 295/453 processed.
# Spectrum 296/453 processed.
# Spectrum 297/453 processed.
# Spectrum 298/453 processed.
# Spectrum 299/453 processed.
# Spectrum 300/453 processed.
# Spectrum 301/453 processed.
# Spectrum 302/453 processed.
# Spectrum 303/453 processed.
# Spectrum 304/453 processed.
# Spectrum 305/453 processed.
# Spectrum 306/453 processed.
# Spectrum 307/453 processed.
# Spectrum 308/453 processed.
# Spectrum 309/453 processed.
# Spectrum 310/453 processed.
# Spectrum 311/453 processed.
# Spectrum 312/453 processed.
# Spectrum 313/453 processed.
# Spectrum 314/453 processed.
# Spectrum 315/453 processed.
# Spectrum 316/453 processed.
# Spectrum 317/453 processed.
# Spectrum 318/453 processed.
# Spectrum 319/453 processed.
# Spectrum 320/453 processed.
# Spectrum 321/453 processed.
# Spectrum 322/453 processed.
# Spectrum 323/453 processed.
# Spectrum 324/453 processed.
# Spectrum 325/453 processed.
# Spectrum 326/453 processed.
# Spectrum 327/453 processed.
# Spectrum 328/453 processed.
# Spectrum 329/453 processed.
# Spectrum 330/453 processed.
# Spectrum 331/453 processed.
# Spectrum 332/453 processed.
# Spectrum 333/453 processed.
# Spectrum 334/453 processed.
# Spectrum 335/453 processed.
# Spectrum 336/453 processed.
# Spectrum 337/453 processed.
# Spectrum 338/453 processed.
# Spectrum 339/453 processed.
# Spectrum 340/453 processed.
# Spectrum 341/453 processed.
# Spectrum 342/453 processed.
# Spectrum 343/453 processed.
# Spectrum 344/453 processed.
# Spectrum 345/453 processed.
# Spectrum 346/453 processed.
# Spectrum 347/453 processed.
# Spectrum 348/453 processed.
# Spectrum 349/453 processed.
# Spectrum 350/453 processed.
# Spectrum 351/453 processed.
# Spectrum 352/453 processed.
# Spectrum 353/453 processed.
# Spectrum 354/453 processed.
# Spectrum 355/453 processed.
# Spectrum 356/453 processed.
# Spectrum 357/453 processed.
# Spectrum 358/453 processed.
# Spectrum 359/453 processed.
# Spectrum 360/453 processed.
# Spectrum 361/453 processed.
# Spectrum 362/453 processed.
# Spectrum 363/453 processed.
# Spectrum 364/453 processed.
# Spectrum 365/453 processed.
# Spectrum 366/453 processed.
# Spectrum 367/453 processed.
# Spectrum 368/453 processed.
# Spectrum 369/453 processed.
# Spectrum 370/453 processed.
# Spectrum 371/453 processed.
# Spectrum 372/453 processed.
# Spectrum 373/453 processed.
# Spectrum 374/453 processed.
# Spectrum 375/453 processed.
# Spectrum 376/453 processed.
# Spectrum 377/453 processed.
# Spectrum 378/453 processed.
# Spectrum 379/453 processed.
# Spectrum 380/453 processed.
# Spectrum 381/453 processed.
# Spectrum 382/453 processed.
# Spectrum 383/453 processed.
# Spectrum 384/453 processed.
# Spectrum 385/453 processed.
# Spectrum 386/453 processed.
# Spectrum 387/453 processed.
# Spectrum 388/453 processed.
# Spectrum 389/453 processed.
# Spectrum 390/453 processed.
# Spectrum 391/453 processed.
# Spectrum 392/453 processed.
# Spectrum 393/453 processed.
# Spectrum 394/453 processed.
# Spectrum 395/453 processed.
# Spectrum 396/453 processed.
# Spectrum 397/453 processed.
# Spectrum 398/453 processed.
# Spectrum 399/453 processed.
# Spectrum 400/453 processed.
# Spectrum 401/453 processed.
# Spectrum 402/453 processed.
# Spectrum 403/453 processed.
# Spectrum 404/453 processed.
# Spectrum 405/453 processed.
# Spectrum 406/453 processed.
# Spectrum 407/453 processed.
# Spectrum 408/453 processed.
# Spectrum 409/453 processed.
# Spectrum 410/453 processed.
# Spectrum 411/453 processed.
# Spectrum 412/453 processed.
# Spectrum 413/453 processed.
# Spectrum 414/453 processed.
# Spectrum 415/453 processed.
# Spectrum 416/453 processed.
# Spectrum 417/453 processed.
# Spectrum 418/453 processed.
# Spectrum 419/453 processed.
# Spectrum 420/453 processed.
# Spectrum 421/453 processed.
# Spectrum 422/453 processed.
# Spectrum 423/453 processed.
# Spectrum 424/453 processed.
# Spectrum 425/453 processed.
# Spectrum 426/453 processed.
# Spectrum 427/453 processed.
# Spectrum 428/453 processed.
# Spectrum 429/453 processed.
# Spectrum 430/453 processed.
# Spectrum 431/453 processed.
# Spectrum 432/453 processed.
# Spectrum 433/453 processed.
# Spectrum 434/453 processed.
# Spectrum 435/453 processed.
# Spectrum 436/453 processed.
# Spectrum 437/453 processed.
# Spectrum 438/453 processed.
# Spectrum 439/453 processed.
# Spectrum 440/453 processed.
# Spectrum 441/453 processed.
# Spectrum 442/453 processed.
# Spectrum 443/453 processed.
# Spectrum 444/453 processed.
# Spectrum 445/453 processed.
# Spectrum 446/453 processed.
# Spectrum 447/453 processed.
# Spectrum 448/453 processed.
# Spectrum 449/453 processed.
# Spectrum 450/453 processed.
# Spectrum 451/453 processed.
# Spectrum 452/453 processed.
# Spectrum 453/453 processed.
# ./path\air_chudo_1_1.mzML "сгенерирован"
